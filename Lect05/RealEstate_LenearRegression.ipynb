# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data = pd.read_csv('real_estate.csv')

# %%
x2 = np.array(data['X2 house age'])
y = np.array(data['Y house price of unit area'])
plt.plot(x2, y, 'k.')
plt.show()

# %%
plt.plot(data['X3 distance to the nearest MRT station'], data['Y house price of unit area'], 'k.')
plt.show()

# %%
x4 = np.array(data['X4 number of convenience stores'])
y = np.array(data['Y house price of unit area'])

plt.plot(x4, y, 'k.')
plt.show()
